# %%
from segmentations.segmentation import segmentation_img
import cv2
import os
import json
import argparse
from argparse import Namespace
from matplotlib import pyplot as plt

# %%
# temp_im = cv2.imread('./../data/Pic1.jpg')
# temp_im = cv2.cvtColor(temp_im, cv2.COLOR_BGR2RGB)

## Ipynotebook version
args = argparse.Namespace(
    model='BEiT_ADE',
    # pcd_path='./../daeyoung/SemanticKITTI/sequences/07/velodyne/*.bin',
    # img2_path='./../daeyoung/SemanticKITTI/sequences/07/image_2/*.png',
    # img3_path='./../daeyoung/SemanticKITTI/sequences/07/image_3/*.png',
    # lbl_path='./../daeyoung/SemanticKITTI/sequences/07/labels/*.label',
    # calib_path='./../daeyoung/SemanticKITTI/sequences/07/calib.txt',
    img_width=380,
    img_height=191,
    output_path='./../data/outputs/',
    log_path='./path/to/log/files')

# %%
mask_im = segmentation_img('./../data/pic2.jpg', args)

plt.imshow(mask_im)
plt.axis('off')
plt.savefig('./../data/pic2_mask.jpg')
plt.show()

# %%
# cv2.imwrite('./../data/Pic1_mask.jpg',mask_im*255.)
plt.imshow(mask_im)
plt.axis('off')
plt.savefig('./../data/pic2_mask.jpg')
plt.show()

# %%
args
# Out:
# Namespace(model='BEiT_ADE', pcd_path='../data/BLKARC-2050377-9.e57', img_width=1024, img_height=512, output_path='/path/to/output/files', log_path='/path/to/log/files')
